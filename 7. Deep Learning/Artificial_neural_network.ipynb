# %% [markdown]
# # Artificial Neural Network

# %% [markdown]
# ### Importing the libraries

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.4.1'

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Importing the dataset

# %%
dataset = pd.read_csv('Churn_Modelling.csv')
x = dataset.iloc[:, 3:-1].values
y = dataset.iloc[:, -1].values

# %%
print(x)
# Out:
# [[619 'France' 'Female' ... 1 1 101348.88]
#  [608 'Spain' 'Female' ... 0 1 112542.58]
#  [502 'France' 'Female' ... 1 0 113931.57]
#  ...
#  [709 'France' 'Female' ... 0 1 42085.58]
#  [772 'Germany' 'Male' ... 1 0 92888.52]
#  [792 'France' 'Female' ... 1 0 38190.78]]

# %%
print(y)
# Out:
# [1 0 1 ... 1 1 0]

# %% [markdown]
# ### Encoding categorical data

# %% [markdown]
# Label Encoding the "Gender" column

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
x[:, 2] = le.fit_transform(x[:, 2])

# %%
print(x)
# Out:
# [[619 'France' 0 ... 1 1 101348.88]
#  [608 'Spain' 0 ... 0 1 112542.58]
#  [502 'France' 0 ... 1 0 113931.57]
#  ...
#  [709 'France' 0 ... 0 1 42085.58]
#  [772 'Germany' 1 ... 1 0 92888.52]
#  [792 'France' 0 ... 1 0 38190.78]]

# %% [markdown]
# One Hot Encoding the "Geography" column

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [1])], remainder='passthrough')
x = np.array(ct.fit_transform(x))

# %%
print(x)
# Out:
# [[1.0 0.0 0.0 ... 1 1 101348.88]
#  [0.0 0.0 1.0 ... 0 1 112542.58]
#  [1.0 0.0 0.0 ... 1 0 113931.57]
#  ...
#  [1.0 0.0 0.0 ... 0 1 42085.58]
#  [0.0 1.0 0.0 ... 1 0 92888.52]
#  [1.0 0.0 0.0 ... 1 0 38190.78]]

# %% [markdown]
# ### Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %% [markdown]
# ## Part 2 - Building the ANN

# %% [markdown]
# ### Initializing the ANN

# %%
ann = tf.keras.models.Sequential()

# %% [markdown]
# ### Adding the input layer and the first hidden layer

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %% [markdown]
# ### Adding the second hidden layer

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %% [markdown]
# ### Adding the output layer

# %%
ann.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# ## Part 3 - Training the ANN

# %% [markdown]
# ### Compiling the ANN

# %%
ann.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ### Training the ANN on the Training set

# %%
ann.fit(x_train, y_train, batch_size = 32, epochs = 100)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 1s 1ms/step - loss: 0.5752 - accuracy: 0.7960
# Epoch 2/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4844 - accuracy: 0.7965
# Epoch 3/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4528 - accuracy: 0.8025
# Epoch 4/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4464 - accuracy: 0.8039
# Epoch 5/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4397 - accuracy: 0.8042
# Epoch 6/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4294 - accuracy: 0.8126
# Epoch 7/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4393 - accuracy: 0.8044
# Epoch 8/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4138 - accuracy: 0.8233
# Epoch 9/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4054 - accuracy: 0.8271
# Epoch 10/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4031 - accuracy: 0.8311
# Epoch 11/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4137 - accuracy: 0.8240
# Epoch 12/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4149 - accuracy: 0.8240
# Epoch 13/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4022 - accuracy: 0.8351
# Epoch 14/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4158 - accuracy: 0.8224
# Epoch 15/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4056 - accuracy: 0.8271
# Epoch 16/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4154 - accuracy: 0.8239
# Epoch 17/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3972 - accuracy: 0.8357
# Epoch 18/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4073 - accuracy: 0.8279
# Epoch 19/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4032 - accuracy: 0.8314
# Epoch 20/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3924 - accuracy: 0.8356
# Epoch 21/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4047 - accuracy: 0.8334
# Epoch 22/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4011 - accuracy: 0.8314
# Epoch 23/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3911 - accuracy: 0.8322
# Epoch 24/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3997 - accuracy: 0.8309
# Epoch 25/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3915 - accuracy: 0.8405
# Epoch 26/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3989 - accuracy: 0.8329
# Epoch 27/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3925 - accuracy: 0.8373
# Epoch 28/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4029 - accuracy: 0.8272
# Epoch 29/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4034 - accuracy: 0.8349
# Epoch 30/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3895 - accuracy: 0.8397
# Epoch 31/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3918 - accuracy: 0.8328
# Epoch 32/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3896 - accuracy: 0.8376
# Epoch 33/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3919 - accuracy: 0.8369
# Epoch 34/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3909 - accuracy: 0.8352
# Epoch 35/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3885 - accuracy: 0.8365
# Epoch 36/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3878 - accuracy: 0.8425
# Epoch 37/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3934 - accuracy: 0.8366
# Epoch 38/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3889 - accuracy: 0.8419
# Epoch 39/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3980 - accuracy: 0.8299
# Epoch 40/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3853 - accuracy: 0.8390
# Epoch 41/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3959 - accuracy: 0.8340
# Epoch 42/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4005 - accuracy: 0.8303
# Epoch 43/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3945 - accuracy: 0.8324
# Epoch 44/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4043 - accuracy: 0.8271
# Epoch 45/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3964 - accuracy: 0.8272
# Epoch 46/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3958 - accuracy: 0.8304
# Epoch 47/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3854 - accuracy: 0.8438
# Epoch 48/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3863 - accuracy: 0.8398
# Epoch 49/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3978 - accuracy: 0.8352
# Epoch 50/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3883 - accuracy: 0.8356
# Epoch 51/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3856 - accuracy: 0.8399
# Epoch 52/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3801 - accuracy: 0.8379
# Epoch 53/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3973 - accuracy: 0.8306
# Epoch 54/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4027 - accuracy: 0.8299
# Epoch 55/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3902 - accuracy: 0.8312
# Epoch 56/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3834 - accuracy: 0.8412
# Epoch 57/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3814 - accuracy: 0.8399
# Epoch 58/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3883 - accuracy: 0.8408
# Epoch 59/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3953 - accuracy: 0.8346
# Epoch 60/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3796 - accuracy: 0.8378
# Epoch 61/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3880 - accuracy: 0.8332
# Epoch 62/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3842 - accuracy: 0.8398
# Epoch 63/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3815 - accuracy: 0.8385
# Epoch 64/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3865 - accuracy: 0.8319
# Epoch 65/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3780 - accuracy: 0.8385
# Epoch 66/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3722 - accuracy: 0.8456
# Epoch 67/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3764 - accuracy: 0.8429
# Epoch 68/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3760 - accuracy: 0.8410
# Epoch 69/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3698 - accuracy: 0.8459
# Epoch 70/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3760 - accuracy: 0.8436
# Epoch 71/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3620 - accuracy: 0.8511
# Epoch 72/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3477 - accuracy: 0.8602
# Epoch 73/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3500 - accuracy: 0.8610
# Epoch 74/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3387 - accuracy: 0.8618
# Epoch 75/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3424 - accuracy: 0.8585
# Epoch 76/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3391 - accuracy: 0.8610
# Epoch 77/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3379 - accuracy: 0.8594
# Epoch 78/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3415 - accuracy: 0.8565
# Epoch 79/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3307 - accuracy: 0.8644
# Epoch 80/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3274 - accuracy: 0.8639
# Epoch 81/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3220 - accuracy: 0.8668
# Epoch 82/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3198 - accuracy: 0.8688
# Epoch 83/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3330 - accuracy: 0.8624
# Epoch 84/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3418 - accuracy: 0.8558
# Epoch 85/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3409 - accuracy: 0.8654
# Epoch 86/100
#  39/250 [===>..........................] - ETA: 0s - loss: 0.3130 - accuracy: 0.8738

# %% [markdown]
# ## Part 4 - Making the predictions and evaluating the model

# %% [markdown]
# ### Predicting the result of a single observation

# %% [markdown]
# **Homework**
#
# Use our ANN model to predict if the customer with the following informations will leave the bank:
#
# Geography: France
#
# Credit Score: 600
#
# Gender: Male
#
# Age: 40 years old
#
# Tenure: 3 years
#
# Balance: \$ 60000
#
# Number of Products: 2
#
# Does this customer have a credit card? Yes
#
# Is this customer an Active Member: Yes
#
# Estimated Salary: \$ 50000
#
# So, should we say goodbye to that customer?

# %% [markdown]
# **Solution**

# %%
print(ann.predict(sc.transform([[1, 0, 0, 600, 1, 40, 3, 60000, 2, 1, 1, 50000]])) > 0.5)

# %% [markdown]
# Therefore, our ANN model predicts that this customer stays in the bank!
#
# **Important note 1:** Notice that the values of the features were all input in a double pair of square brackets. That's because the "predict" method always expects a 2D array as the format of its inputs. And putting our values into a double pair of square brackets makes the input exactly a 2D array.
#
# **Important note 2:** Notice also that the "France" country was not input as a string in the last column but as "1, 0, 0" in the first three columns. That's because of course the predict method expects the one-hot-encoded values of the state, and as we see in the first row of the matrix of features x, "France" was encoded as "1, 0, 0". And be careful to include these values in the first three columns, because the dummy variables are always created in the first columns.

# %% [markdown]
# ### Predicting the Test set results

# %%
y_pred = ann.predict(x_test)
y_pred = (y_pred > 0.5)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

# %% [markdown]
# ### Making the Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
